# %%
#%matplotlib notebook
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

player_salary = 'https://hoopshype.com/salaries/players/'
team_salary = 'https://hoopshype.com/salaries/'

# %%
#This is building a list of years from 2000 to 2020 for the years we are going to scrape
years = []
for x in range(2001,2022):
    years.append(x)

print(years)
len(years)
# Out:
# [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# 21

# %%
#This starts with a blank list and loops through the salaries and then stores it into a list
playerList = []
for y in years:
    #This one indexes the player name and looks cleaner
    #Psalary = pd.read_html(f"https://hoopshype.com/salaries/players/{y-1}-{y}", header=0, index_col=1)
    #Using this one below allows for the player name to be extracted below, cant do it if name is the index
    Psalary = pd.read_html(f"https://hoopshype.com/salaries/players/{y-1}-{y}", header=0)
    playerList.append(Psalary)

# %%
#This reads the lists of players and salary then puts it into a dataframe
#This will work but the index cant be the name of the player, cannot index in the for loop above
raw_data = {"Player-00":playerList[0][0]['Player'],"2000":playerList[0][0]['2000/01'],
            "Player-01":playerList[1][0]['Player'],"2001":playerList[1][0]['2001/02'],
           }
sal = pd.DataFrame(raw_data)
sal
# Out:
#             Player-00         2000         Player-01         2001
# 0       Kevin Garnett  $19,610,000     Kevin Garnett  $22,400,000
# 1    Shaquille O'Neal  $19,285,715  Shaquille O'Neal  $21,428,572
# 2     Alonzo Mourning  $16,880,000   Alonzo Mourning  $18,754,800
# 3        Juwan Howard  $16,875,000      Juwan Howard  $18,750,000
# 4     Hakeem Olajuwon  $16,700,000    Scottie Pippen  $18,083,564
# ..                ...          ...               ...          ...
# 450      Garth Joseph     $316,969               NaN          NaN
# 451        Mike Smith     $316,969               NaN          NaN
# 452      Mark Karcher      $50,000               NaN          NaN
# 453    Anthony Miller      $40,000               NaN          NaN
# 454    Jamal Robinson      $40,000               NaN          NaN
#
# [455 rows x 4 columns]

# %%
#There are 20 years worth of data, each is its own list that can be called
#Note: The first bracket selects the year from the list, the second tells pandas to convert to a dataframe
df00 = pd.DataFrame(playerList[0][0])
df01 = pd.DataFrame(playerList[1][0])
df02 = pd.DataFrame(playerList[2][0])
df03 = pd.DataFrame(playerList[3][0])
df04 = pd.DataFrame(playerList[4][0])
df05 = pd.DataFrame(playerList[5][0])
df06 = pd.DataFrame(playerList[6][0])
df07 = pd.DataFrame(playerList[7][0])
df08 = pd.DataFrame(playerList[8][0])
df09 = pd.DataFrame(playerList[9][0])
df10 = pd.DataFrame(playerList[10][0])
df11 = pd.DataFrame(playerList[11][0])
df12 = pd.DataFrame(playerList[12][0])
df13 = pd.DataFrame(playerList[13][0])
df14 = pd.DataFrame(playerList[14][0])
df15 = pd.DataFrame(playerList[15][0])
df16 = pd.DataFrame(playerList[16][0])
df17 = pd.DataFrame(playerList[17][0])
df18 = pd.DataFrame(playerList[18][0])
df19 = pd.DataFrame(playerList[19][0])
df20 = pd.DataFrame(playerList[20][0])
df18
# Out:
#      Unnamed: 0             Player      2018/19   2018/19(*)
# 0           1.0      Stephen Curry  $37,457,154  $38,074,629
# 1           2.0  Russell Westbrook  $35,665,000  $36,252,932
# 2           3.0         Chris Paul  $35,654,150  $36,241,903
# 3           3.0       LeBron James  $35,654,150  $36,241,903
# 4           5.0         Kyle Lowry  $32,700,000  $33,239,054
# ..          ...                ...          ...          ...
# 571       566.0      Dusty Hannahs      $47,370      $48,150
# 572       566.0      Kendrick Nunn      $47,370      $48,150
# 573       566.0    Richard Solomon      $47,370      $48,150
# 574       566.0         Cody Demps      $47,370      $48,150
# 575       566.0      Tarik Phillip      $47,370      $48,150
#
# [576 rows x 4 columns]

# %%
#This starts with a blank list and loops through the team salaries and then stores it into a list
teamList = []
for y in years:
    Tsalary = pd.read_html(f"https://hoopshype.com/salaries/{y-1}-{y}/", header=0, index_col=1)
    teamList.append(Tsalary)

# %%
#There are 20 years worth of data, each is its own list that can be called
#Note: The first bracket selects the year from the list, the second tells pandas to convert to a dataframe
Team_df00 = pd.DataFrame(teamList[0][0])
Team_df01 = pd.DataFrame(teamList[1][0])
Team_df02 = pd.DataFrame(teamList[2][0])
Team_df03 = pd.DataFrame(teamList[3][0])
Team_df04 = pd.DataFrame(teamList[4][0])
Team_df05 = pd.DataFrame(teamList[5][0])
Team_df06 = pd.DataFrame(teamList[6][0])
Team_df07 = pd.DataFrame(teamList[7][0])
Team_df08 = pd.DataFrame(teamList[8][0])
Team_df09 = pd.DataFrame(teamList[9][0])
Team_df10 = pd.DataFrame(teamList[10][0])
Team_df11 = pd.DataFrame(teamList[11][0])
Team_df12 = pd.DataFrame(teamList[12][0])
Team_df13 = pd.DataFrame(teamList[13][0])
Team_df14 = pd.DataFrame(teamList[14][0])
Team_df15 = pd.DataFrame(teamList[15][0])
Team_df16 = pd.DataFrame(teamList[16][0])
Team_df17 = pd.DataFrame(teamList[17][0])
Team_df18 = pd.DataFrame(teamList[18][0])
Team_df19 = pd.DataFrame(teamList[19][0])
Team_df20 = pd.DataFrame(teamList[20][0])
Team_df18
# Out:
#                Unnamed: 0       2018/19    2018/19(*)
# Team
# Miami                 1.0  $153,171,497  $155,696,495
# Golden State          2.0  $146,291,276  $148,702,858
# Oklahoma City         3.0  $144,916,427  $147,305,340
# Toronto               4.0  $137,793,831  $140,065,330
# Milwaukee             5.0  $130,988,604  $133,147,922
# Portland              6.0  $130,256,600  $132,403,851
# Detroit               7.0  $126,557,932  $128,644,207
# Houston               8.0  $126,474,100  $128,558,994
# Memphis               9.0  $126,107,461  $128,186,312
# Boston               10.0  $125,334,993  $127,401,110
# Washington           11.0  $123,747,588  $125,787,536
# New York             12.0  $123,387,454  $125,421,469
# Cleveland            13.0  $123,255,073  $125,286,901
# Minnesota            14.0  $121,962,221  $123,972,737
# San Antonio          15.0  $121,588,790  $123,593,153
# Charlotte            16.0  $121,427,859  $123,429,571
# ...

# %%
#This starts with a blank list and loops through the salaries and then stores it into a list
# playerList = []
# x=0
# for y in years:
#     Psalary = pd.read_html(f"https://hoopshype.com/salaries/players/{y-1}-{y}/")
#     playerList.append(Psalary)

#     player_df = pd.DataFrame()
    
#     #this is building the column titles to store the player data
#     player_df[f'{y-1}-{y}'] = playerList[x][0]
#     print(player_df[f'{y-1}-{y}'])
#     x=x+1

# %%
#This will now loop through all the dataframes previously created and merge all of them into one with team name
#as the index and all the years as the columns

# %%
#This repeats the process for the individual top 100 players for 20 years

# %%
#You could also just look at the statistics of the top 10 players over time
#As new players come into the top ten then that is fine, it may show if talent is getting better over time

# %%
#This is pulling in the sheet with player stats and salaries on a single html table
player_Salaries = pd.read_html('https://www.spotrac.com/nba/statistics/player/')
player_Salaries[0]
# Out:
#                   Rank Player  Pos  Team    GP   MIN    PTS    FG%    3P%  \
# 0           Chris Paul     PG  OKC    63  2003  1114  48.94  36.20  90.00
# 1    Russell Westbrook     PG  HOU    53  1904  1456  47.37  25.37  77.75
# 2         James Harden     SG  HOU    61  2241  2096  43.51  35.24  86.09
# 3         LeBron James     SF  LAL    60  2094  1544  49.83  34.91  69.68
# 4           Kyle Lowry     PG  TOR    52  1900  1026  41.70  35.42  86.15
# ..                 ...    ...  ...   ...   ...   ...    ...    ...    ...
# 330    Marvin Williams     PF  MIL    52  1010   319  44.18  36.11  87.04
# 331         Jeff Green     SF  HOU    80  1508   674  44.44  34.78  78.08
# 332    Brandon Goodwin     PG  ATL    34   430   206  40.00  29.89  93.33
# 333        Chris Silva      F  MIA    41   306   120  62.32   0.00  69.39
# 334          Ky Bowman     SG  GSW    45  1015   335  41.74  30.84  82.93
#
#      FT%  AST  BLK  STL  REB              TOV  Cap
# ...

# %%
#Putting into a DataFrame
playerdf = pd.DataFrame(player_Salaries[0])

# %%
#This is splitting out the salary by itself from the parenthesis and number
playerdf[['Salary','Num']]=playerdf.TOV.str.split(expand=True)
playerdf
# Out:
#                   Rank Player  Pos  Team    GP   MIN    PTS    FG%    3P%  \
# 0           Chris Paul     PG  OKC    63  2003  1114  48.94  36.20  90.00
# 1    Russell Westbrook     PG  HOU    53  1904  1456  47.37  25.37  77.75
# 2         James Harden     SG  HOU    61  2241  2096  43.51  35.24  86.09
# 3         LeBron James     SF  LAL    60  2094  1544  49.83  34.91  69.68
# 4           Kyle Lowry     PG  TOR    52  1900  1026  41.70  35.42  86.15
# ..                 ...    ...  ...   ...   ...   ...    ...    ...    ...
# 330    Marvin Williams     PF  MIL    52  1010   319  44.18  36.11  87.04
# 331         Jeff Green     SF  HOU    80  1508   674  44.44  34.78  78.08
# 332    Brandon Goodwin     PG  ATL    34   430   206  40.00  29.89  93.33
# 333        Chris Silva      F  MIA    41   306   120  62.32   0.00  69.39
# 334          Ky Bowman     SG  GSW    45  1015   335  41.74  30.84  82.93
#
#      FT%  AST  BLK  STL  REB              TOV  Cap       Salary    Num  \
# ...

# %%
#This will attempt to remove the '$' from salary to convert to a number and store in a new column
playerdf['$ Salary'] = playerdf['Salary'].str.replace(',','').str.replace('$','').astype(int)
playerdf
# Out:
#                   Rank Player  Pos  Team    GP   MIN    PTS    FG%    3P%  \
# 0           Chris Paul     PG  OKC    63  2003  1114  48.94  36.20  90.00
# 1    Russell Westbrook     PG  HOU    53  1904  1456  47.37  25.37  77.75
# 2         James Harden     SG  HOU    61  2241  2096  43.51  35.24  86.09
# 3         LeBron James     SF  LAL    60  2094  1544  49.83  34.91  69.68
# 4           Kyle Lowry     PG  TOR    52  1900  1026  41.70  35.42  86.15
# ..                 ...    ...  ...   ...   ...   ...    ...    ...    ...
# 330    Marvin Williams     PF  MIL    52  1010   319  44.18  36.11  87.04
# 331         Jeff Green     SF  HOU    80  1508   674  44.44  34.78  78.08
# 332    Brandon Goodwin     PG  ATL    34   430   206  40.00  29.89  93.33
# 333        Chris Silva      F  MIA    41   306   120  62.32   0.00  69.39
# 334          Ky Bowman     SG  GSW    45  1015   335  41.74  30.84  82.93
#
#      FT%  AST  BLK  STL  REB              TOV  Cap       Salary    Num  \
# ...

# %%
# File to Load from Jason and Antonia
file = "Resources/cvs_for_import.csv"

# Read Purchasing File and store into Pandas data frame
playerdf = pd.read_csv(file)
playerdf
# Out:
#               Player Position TEAM  GP   MIN   PTS   FG%   3P%    FT%  AST  \
# 0      Stephen Curry       PG  GSW   5   139   104  40.2  24.5  100.0   33
# 1       James Harden       PG  HOU  61  2241  2096  43.5  35.2   86.1  450
# 2       LeBron James       SF  LAL  60  2094  1544  49.8  34.9   69.7  636
# 3         Kyle Lowry       PG  TOR  52  1901  1026  41.7  35.4   86.1  399
# 4      Blake Griffin       PF  DET  18   512   279  35.2  24.3   77.6   59
# ..               ...      ...  ...  ..   ...   ...   ...   ...    ...  ...
# 274  DeMarre Carroll       SF  SAS  15   135    33  31.0  23.1   60.0   11
# 275   Reggie Jackson       PG  DET  14   381   209  38.4  37.8   78.8   72
# 276       Jeff Green       SF  UTA  30   553   233  38.5  32.7   77.8   20
# 277     Troy Daniels       SG  LAL  41   456   174  39.2  35.7   62.5   14
# 278        Ky Bowman       PG  GSW  45  1015   335  41.7  30.8   82.9  131
#
#      BLK  STL  REB  TOV    Salary
# ...

# %%
def linreg(x_values,y_values):
    #Building the linear regression function
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept

    # Create line equation string
    global line_eq
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

    # Create Plot
    #plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    
    # Print r square value
    print(f"The r-squared is: {rvalue}")

# %%
#Here I am setting up the scatter plot with the axis spacing and rotation

#sal = playerdf['Salary'].apply(lambda x: '${0:,.0f}'.format((x/1000)))
sal = playerdf['Salary']/1000
pts = playerdf['PTS']

plt.scatter(sal,pts, marker="o",color='forestgreen',  edgecolors="black",
            s=50, alpha=0.75)
plt.xlabel("Salaries, $K")
plt.ylabel("Points per Season")
plt.title('How Does Salary Affect Points per Year?')

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,pts)
plt.annotate(line_eq,(0,2000),fontsize=15,color="darkgreen")
plt.show()
# Out:
# The r-squared is: 0.5736421569986094

# %%
sal = playerdf['Salary']/1000
gp = playerdf['GP']
ppg = pts/gp

plt.scatter(sal,ppg, marker="o",color='forestgreen',  edgecolors="black",
            s=50, alpha=0.75)
plt.xlabel("Salaries, $K")
plt.ylabel("Points per Game")
plt.title('How Does Salary Affect Points per Game?')

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,ppg)
plt.annotate(line_eq,(0,31),fontsize=15,color="darkgreen")
plt.show()
# Out:
# The r-squared is: 0.6507022780169511

# %%
#I am using binned data to see how salaries are distributed
bins = [-1,250,500,1000,2500,5000,10000,15000,20000,25000,30000,35000,50000]
group_names = ['$0-250k','$250-500k','$500-1M','$1-2.5M',
               '$2.5-5M','$5-10M','$10-15M','$15-20M','$20-25M',
               '$25-30M','$30-35M','$35M+']
playerdf["Salary Summary"] = pd.cut(playerdf["Salary"]/1000, bins, labels=group_names)
sal_group = playerdf.groupby(['Salary Summary'])

#This displays the number of players in each salary group
count = sal_group['Salary Summary'].count()
print(count)

#This shows the averave points per year scored per million dollars spent
sal_avg = sal_group['Salary'].mean()
pt_avg = sal_group['PTS'].mean()
group_val = (pt_avg/(sal_avg/1000000))
print(round(group_val,1))
# Out:
# Salary Summary
# $0-250k       0
# $250-500k     3
# $500-1M      21
# $1-2.5M      75
# $2.5-5M      58
# $5-10M       49
# $10-15M      20
# $15-20M      17
# $20-25M       5
# $25-30M      17
# $30-35M      11
# $35M+         3
# Name: Salary Summary, dtype: int64
# Salary Summary
# $0-250k        NaN
# $250-500k    631.9
# $500-1M      201.4
# $1-2.5M      167.9
# $2.5-5M      113.8
# $5-10M        75.3
# $10-15M       40.2
# $15-20M       34.3
# $20-25M       41.8
# $25-30M       41.1
# $30-35M       26.6
# $35M+         32.3
# dtype: float64

# %%
xaxis = ['$0-250k','$250-500k','$500-1M','$1-2.5M',
               '$2.5-5M','$5-10M','$10-15M','$15-20M','$20-25M',
               '$25-30M','$30-35M','$35M+']
plt.bar(xaxis,group_val, color = 'forestgreen', edgecolor='black')
plt.tick_params(axis ='x', rotation = 45)
plt.ylabel("Avg Points per Million Dollars")
# Out:
# Text(0, 0.5, 'Avg Points per Million Dollars')

# %%
#Histogram of players salaries in the NBA
#player_small = playerdf['$ Salary']/1000 
#player_small.hist(bins = 50, facecolor='g', alpha=0.75)
n, bins, patches = plt.hist(playerdf['Salary']/1000, 50, edgecolor='black', facecolor='g', alpha=0.75)
plt.xticks(np.arange(0, 40001, 3000))
plt.tick_params(axis ='x', rotation = 45)
#plt.gca().invert_xaxis()
plt.title("How are Salaries Distributed in the NBA?")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#This is calculating the statistics on the points scored
#I need to convert these values to dollars
sal_num = playerdf['Salary']/1000
sal_std = np.std(sal_num,ddof=0)

print(f'The standard deviation is {round(sal_std,1)}')
      
quartiles = sal_num.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The median of player salary is: {quartiles[0.5]} ")

print(f"The lower quartile of player salary is: {round(lowerq,1)}")
print(f"The upper quartile of player salary is: {round(upperq,1)}")
print(f"The interquartile range of player salary is: {round(iqr,1)}")


lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound,1)} could be outliers.")
print(f"Values above {round(upper_bound,1)} could be outliers.")
# Out:
# The standard deviation is 9298.4
# The median of player salary is: 4102.564
# The lower quartile of player salary is: 1677.8
# The upper quartile of player salary is: 11148.9
# The interquartile range of player salary is: 9471.1
# Values below -12528.8 could be outliers.
# Values above 25355.5 could be outliers.

# %%
#Boxplot of average points per game
fig1, ax1 = plt.subplots()
ax1.set_title('Players Salary Distribution')
ax1.set_ylabel('Players Salaries')
ax1.boxplot(sal_num)
plt.show
#This shows that there are outliers starting around $28MM per year
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#This is calculating the statistics on the points scored
pts_std = np.std(pts,ddof=0)
print(f'The standard deviation is {round(pts_std,1)}')
      
quartiles = pts.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of average points is: {round(lowerq,1)}")
print(f"The upper quartile of average points is: {round(upperq,1)}")
print(f"The interquartile range of average points is: {round(iqr,1)}")
print(f"The the median of average points is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound,1)} could be outliers.")
print(f"Values above {round(upper_bound,1)} could be outliers.")
# Out:
# The standard deviation is 397.3
# The lower quartile of average points is: 199.5
# The upper quartile of average points is: 679.0
# The interquartile range of average points is: 479.5
# The the median of average points is: 375.0
# Values below -519.8 could be outliers.
# Values above 1398.2 could be outliers.

# %%
pt_3 = playerdf['3P%']

plt.scatter(sal,pt_3, marker="o", color = 'darkcyan', edgecolors="black",
            s=50, alpha=0.6, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("3pt Percentage")
plt.ylim(10,70)
plt.title("3 Point % vs Salary")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,pt_3)
plt.annotate(line_eq,(22000,15),fontsize=15,color="darkcyan")
plt.show()
# Out:
# The r-squared is: 0.10366636068990433

# %%
play_freetrw = playerdf['FT%']

plt.scatter(sal,play_freetrw, marker="o", color='blue',  edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("Free Throw %")
plt.ylim(40,109)
plt.title("Free Throws vs Salary")


plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_freetrw)
plt.annotate(line_eq,(22000,45),fontsize=15,color="blue")
plt.show()
# Out:
# The r-squared is: 0.16385352856860064

# %%
play_min = playerdf['MIN']

plt.scatter(sal,play_min, marker="o", color='orange', edgecolors="black",
            s=50, alpha=0.6, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("Minutes Played")
plt.title("Salary vs Time in Game?")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_min)
plt.annotate(line_eq,(21000,45),fontsize=15,color="darkgoldenrod")
plt.show()
# Out:
# The r-squared is: 0.4608377457082163

# %%
play_games = playerdf['GP']

plt.scatter(sal,play_games, marker="o",color='blue',  edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("Games Played")
plt.ylim(5,70)
plt.title("Games Played vs Salary")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_games)
plt.annotate(line_eq,(21000,7),fontsize=15,color="blue")
plt.show()
# Out:
# The r-squared is: 0.18602078585717674

# %%
play_fldgls = playerdf['FG%']

plt.scatter(sal,play_fldgls, marker="o", color='darkcyan', edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("Field Goal %")
plt.ylim(10,81)
plt.title("Field Goal % vs Salary")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_fldgls)
plt.annotate(line_eq,(21000,13),fontsize=15,color="darkcyan")
plt.show()
# Out:
# The r-squared is: 0.09078157536827926

# %%
play_asst = playerdf['AST']


plt.scatter(sal,play_asst, marker="o", color='cornflowerblue', edgecolors="black",
            s=60, alpha=0.65, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("No. of Assists")
#plt.ylim(10,81)
plt.title("Salary vs Assists")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_asst)
plt.annotate(line_eq,(0,600),fontsize=15,color="blue")
plt.show()
# Out:
# The r-squared is: 0.5355900715236912

# %%
play_blk = playerdf['BLK']

plt.scatter(sal,play_blk, marker="o", color='blue', edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("No of Blocks")
#plt.ylim(10,81)
plt.title("Salary vs Blocks")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_blk)
plt.annotate(line_eq,(0,130),fontsize=15,color="blue")
plt.show()
# Out:
# The r-squared is: 0.25316078589848906

# %%
play_stl = playerdf['STL']

plt.scatter(sal,play_stl, marker="o", color='firebrick', edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("No. of Steals")
#plt.ylim(10,81)
plt.title("Salary vs Steals")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_stl)
plt.annotate(line_eq,(18000,0),fontsize=15,color="black")
plt.show()
# Out:
# The r-squared is: 0.4047137278800847

# %%
play_reb = playerdf['REB']

plt.scatter(sal,play_reb, marker="o", color='blue', edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("Field Goal %")
#plt.ylim(10,81)
plt.title("Salary vs Rebounds")

plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
linreg(sal,play_reb)
plt.annotate(line_eq,(18000,0),fontsize=15,color="blue")
plt.show()
# Out:
# The r-squared is: 0.4457962447482943

# %%
#Boxplot of average points per game
fig2, ax2 = plt.subplots()
ax2.set_title('Points per Game Distribution')
ax2.set_ylabel('Avg Points per Game')
ax2.boxplot(pts)
plt.show
#This shows that there are outliers starting around 60pts per game
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#This doesnt really show anything. It just removes the points beyond $28MM

#This will remove the outliers from the dataset and rechart 
no_otlr_sal = playerdf.loc[playerdf['$ Salary'] <=28000000,:]
#no_outliers_sal = no_outliers_pts.loc[playerdf['PTS'] >=31,:]

#This is plotting the data without the outliers in it
pts_na = no_otlr_sal['PTS']
sal_na = no_otlr_sal['$ Salary']/1000
plt.scatter(sal_na,pts_na, marker="o",  edgecolors="black",
            s=50, alpha=0.5, cmap="plasma")
plt.xlabel("Salaries")
plt.ylabel("Avg Points per Game")
plt.xticks(np.arange(0, 40001, 5000))
plt.tick_params(axis ='x', rotation = 45)
#plt.gca().invert_xaxis()
plt.title("Point vs Salary without Points' Outliers")
plt.show()
